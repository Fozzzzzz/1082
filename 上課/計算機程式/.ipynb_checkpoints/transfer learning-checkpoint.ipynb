# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD

# %%
from tensorflow.keras.datasets import mnist, fashion_mnist

# %%
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### 讀取資料並整理

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.reshape(60000, 28, 28, 1)/225
x_test = x_test.reshape(10000, 28, 28, 1)/225

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ### 建立神經網路層

# %%
Conv_layer=[Conv2D(16, (3,3), padding='same', input_shape=(28,28,1)),
            Activation('relu'), 
            MaxPooling2D(pool_size=(2,2)),
                   
            Conv2D(32, (3,3), padding='same'),
            Activation('relu'),
            MaxPooling2D(pool_size=(2,2)),
                   
            Conv2D(64, (3,3), padding='same'),
            Activation('relu'),
            MaxPooling2D(pool_size=(2,2)),
                   
            Conv2D(128, (3,3), padding='same'),
            Activation('relu'),
            MaxPooling2D(pool_size=(2,2))]
fla_layer=[Flatten(),
           Dense(35), Activation('relu'),
           Dense(78), Activation('relu'),
           Dense(10), Activation('softmax')]

# %%
model=Sequential(Conv_layer + fla_layer)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 3, 128)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 35)                4515
# _________________________________________________________________
# activation_4 (Activation)    (None, 35)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 78)                2808
# _________________________________________________________________
# activation_5 (Activation)    (None, 78)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                790
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 105,265
# Trainable params: 105,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer=SGD(lr=0.87),metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size=100, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 50s 829us/sample - loss: 0.0629 - accuracy: 0.4868
# Epoch 2/10
# 60000/60000 [==============================] - 47s 782us/sample - loss: 0.0314 - accuracy: 0.7744
# Epoch 3/10
# 60000/60000 [==============================] - 48s 792us/sample - loss: 0.0241 - accuracy: 0.8293
# Epoch 4/10
# 60000/60000 [==============================] - 45s 747us/sample - loss: 0.0208 - accuracy: 0.8552
# Epoch 5/10
# 60000/60000 [==============================] - 45s 753us/sample - loss: 0.0188 - accuracy: 0.8698
# Epoch 6/10
# 60000/60000 [==============================] - 47s 777us/sample - loss: 0.0174 - accuracy: 0.8815
# Epoch 7/10
# 60000/60000 [==============================] - 46s 768us/sample - loss: 0.0164 - accuracy: 0.8870
# Epoch 8/10
# 60000/60000 [==============================] - 40s 663us/sample - loss: 0.0155 - accuracy: 0.8935
# Epoch 9/10
# 60000/60000 [==============================] - 42s 698us/sample - loss: 0.0148 - accuracy: 0.8992
# Epoch 10/10
# 60000/60000 [==============================] - 51s 843us/sample - loss: 0.0142 - accuracy: 0.9036

# %% [markdown]
# ### 保留convolutional layers，做新的神經網路

# %%
mnist_fla_layer=[Flatten(),
                 Dense(53), Activation('relu'),
                 Dense(10), Activation('softmax')]

# %%
mnist_model=Sequential(Conv_layer + mnist_fla_layer)

# %%
mnist_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 3, 128)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 53)                6837
# _________________________________________________________________
# activation_7 (Activation)    (None, 53)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                540
# _________________________________________________________________
# activation_8 (Activation)    (None, 10)                0
# =================================================================
# Total params: 104,529
# Trainable params: 104,529
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 將借來的神經網路冷凍起來

# %%
for layer in Conv_layer:
    layer.trainable = False

# %%
mnist_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 3, 128)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 53)                6837
# _________________________________________________________________
# activation_7 (Activation)    (None, 53)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                540
# _________________________________________________________________
# activation_8 (Activation)    (None, 10)                0
# =================================================================
# Total params: 104,529
# Trainable params: 7,377
# Non-trainable params: 97,152
# _________________________________________________________________

# %%
(new_x_train, new_y_train), (new_x_test, new_y_test) = mnist.load_data()

# %%
new_x_train = new_x_train.reshape(60000, 28, 28, 1)/225
new_x_test = new_x_test.reshape(10000, 28, 28, 1)/225

# %%
new_y_train = to_categorical(new_y_train, 10)
new_y_test = to_categorical(new_y_test, 10)

# %%
mnist_model.compile(loss='mse', optimizer=SGD(lr=0.059), metrics=['accuracy'])

# %%
mnist_model.fit(new_x_train, new_y_train, batch_size=128, epochs=12)
# Out:
# Train on 60000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 15s 244us/sample - loss: 0.0873 - accuracy: 0.1799
# Epoch 2/12
# 60000/60000 [==============================] - 14s 229us/sample - loss: 0.0790 - accuracy: 0.3507
# Epoch 3/12
# 60000/60000 [==============================] - 14s 229us/sample - loss: 0.0721 - accuracy: 0.4846
# Epoch 4/12
# 60000/60000 [==============================] - 15s 242us/sample - loss: 0.0643 - accuracy: 0.5701
# Epoch 5/12
# 60000/60000 [==============================] - 16s 264us/sample - loss: 0.0568 - accuracy: 0.6326
# Epoch 6/12
# 60000/60000 [==============================] - 12s 203us/sample - loss: 0.0503 - accuracy: 0.6834
# Epoch 7/12
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.0447 - accuracy: 0.7245
# Epoch 8/12
# 60000/60000 [==============================] - 13s 211us/sample - loss: 0.0400 - accuracy: 0.7574
# Epoch 9/12
# 60000/60000 [==============================] - 14s 228us/sample - loss: 0.0362 - accuracy: 0.7836
# Epoch 10/12
# 60000/60000 [==============================] - 14s 231us/sample - loss: 0.0331 - accuracy: 0.8018
# Epoch 11/12
# 60000/60000 [==============================] - 14s 229us/sample - loss: 0.0306 - accuracy: 0.8157
# Epoch 12/12
# 60000/60000 [==============================] - 13s 221us/sample - loss: 0.0287 - accuracy: 0.8260

# %% [markdown]
# ### 查看預測結果

# %%
score = mnist_model.evaluate(new_x_test, new_y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
loss, acc = score

# %%
print('測試資料正確率', acc)
# Out:
# 測試資料正確率 0.8415
